# %% [markdown]
# # Test to use SAM3 for video
# ## Import libraries

# %%
import glob
import os
import sam3
from sam3.model_builder import build_sam3_video_predictor
import torch

# %% [markdown]
# ## parameters

# %%
video_path = "./assets/videos/0001"

# %% [markdown]
# ## load model

# %%
gpus_to_use = range(torch.cuda.device_count())
print(gpus_to_use)

# %%
predictor = build_sam3_video_predictor(gpus_to_use=gpus_to_use)

# %% [markdown]
# ## Load video

# %%
response = predictor.handle_stream_request(
    request=dict(
        type="start_session",
        session_id=video_path,
    )
)
